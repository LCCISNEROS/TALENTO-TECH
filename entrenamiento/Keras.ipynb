# %% [markdown]
# <a href="https://colab.research.google.com/github/LCCISNEROS/TALENTO-TECH/blob/main/entrenamiento/Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow.keras as kr
import numpy as np

from IPython.core.display import display, HTML

lr = 0.01                        # learning rate
nn = [2, 16, 8, 1]               # número de neuronas por capa.

# Create dummy data for X and Y
X = np.random.rand(100, 2)  # 100 samples, 2 features
Y = np.random.rand(100, 1)  # 100 samples, 1 output

# Creamos el objeto que contendrá a nuestra red neuronal, como secuencia de capas.
model = kr.Sequential()

# Añadimos la capa 1
l1 = model.add(kr.layers.Dense(nn[1], activation='relu'))

# Añadimos la capa 2
l2 = model.add(kr.layers.Dense(nn[2], activation='relu'))

# Añadimos la capa 3
l3 = model.add(kr.layers.Dense(nn[3], activation='sigmoid'))

# Compilamos el modelo, definiendo la función de coste y el optimizador.
model.compile(loss='mse', optimizer=kr.optimizers.SGD(learning_rate=0.05), metrics=['acc'])

# Y entrenamos al modelo. Los callbacks
model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.0000e+00 - loss: 0.1112
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.0000e+00 - loss: 0.1029
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.0000e+00 - loss: 0.1083
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.0000e+00 - loss: 0.1083
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.0000e+00 - loss: 0.1120
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.0000e+00 - loss: 0.0984
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.0000e+00 - loss: 0.0963
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.0000e+00 - loss: 0.0973
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.0000e+00 - loss: 0.1075
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.0000e+00 - loss: 0.1028
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.0000e+00 - loss: 0.0999
# Epoch 12/100
# ...

# %%
import numpy as np

# Create dummy data for X and Y
X = np.random.rand(100, 2)  # 100 samples, 2 features
Y = np.random.rand(100, 1)  # 100 samples, 1 output
