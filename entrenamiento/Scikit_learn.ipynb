# %% [markdown]
# <a href="https://colab.research.google.com/github/LCCISNEROS/TALENTO-TECH/blob/main/entrenamiento/Scikit_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn as sk
import sklearn.neural_network
import numpy as np # Import numpy as it's used for the example data

from IPython.core.display import display, HTML

# Define X and Y here. Replace with your actual data loading or generation.
# Example:
X = np.random.rand(100, 2) # Example features (100 samples, 2 features)
Y = np.random.rand(100, 1) # Example target (100 samples, 1 target)


lr = 0.01                       # learning rate
nn = [2, 16, 8, 1]              # número de neuronas por capa.

# Creamos el objeto del modelo de red neuronal multicapa.
clf = sk.neural_network.MLPRegressor(
    solver='sgd',
    learning_rate_init=lr,
    hidden_layer_sizes=tuple(nn[1:]),
    verbose=True,
    n_iter_no_change=1000,
    batch_size=64,
    max_iter=500 # Aumentamos el número máximo de iteraciones
)

# Reformamos Y para que sea un array 1D
Y = Y.ravel()

# Y lo entrenamos con nuestros datos.
clf.fit(X, Y)
# Out:
# Iteration 1, loss = 0.06450937
# Iteration 2, loss = 0.06104000
# Iteration 3, loss = 0.05779558
# Iteration 4, loss = 0.05604234
# Iteration 5, loss = 0.05506982
# Iteration 6, loss = 0.05432329
# Iteration 7, loss = 0.05287336
# Iteration 8, loss = 0.05127373
# Iteration 9, loss = 0.04969225
# Iteration 10, loss = 0.04852956
# Iteration 11, loss = 0.04782543
# Iteration 12, loss = 0.04664705
# Iteration 13, loss = 0.04594801
# Iteration 14, loss = 0.04546978
# Iteration 15, loss = 0.04479177
# Iteration 16, loss = 0.04457128
# Iteration 17, loss = 0.04426631
# Iteration 18, loss = 0.04408621
# Iteration 19, loss = 0.04381271
# Iteration 20, loss = 0.04359662
# Iteration 21, loss = 0.04337975
# Iteration 22, loss = 0.04317139
# Iteration 23, loss = 0.04298591
# Iteration 24, loss = 0.04285328
# Iteration 25, loss = 0.04274890
# Iteration 26, loss = 0.04262292
# Iteration 27, loss = 0.04241985
# Iteration 28, loss = 0.04224844
# Iteration 29, loss = 0.04217674
# ...

# %%
# Define X and Y here. Replace with your actual data loading or generation.
# Example:
import numpy as np
X = np.random.rand(100, 2) # Example features (100 samples, 2 features)
Y = np.random.rand(100, 1) # Example target (100 samples, 1 target)
